# %% [markdown]
# ## Question 10 : Création d'un petit logiciel d'analyse du cours de l'action d'Olympus
#
# Pour ceux qui ne le savaient pas, avant de devenir Evident Scientific, cette entreprise était en réalité la division industrielle d'Olympus. Au cours de l'année écoulée, l'entreprise s'est séparée du géant Olympus pour devenir autonome.
#
# Afin de visualiser l'impact de la vente d'une partie de l'entreprise sur le cours de l'action d'Olympus, nous vous demandons de créer un outil de visualisation du cours de l'action d'Olympus en utilisant Python.
#
# Nous vous demandons que les données affichées dans votre application proviennent de l'API suivante : [Yahoo Finance](https://docs.marketdata.app/api). Vous pourrai retrouver la documentation de cet api ici : [Swagger](https://api.marketdata.app/#/v1/v1_indices_candles_retrieve) . L'action que nous vous demandons de suivre est la suivante : **Olympus Corporation (OLYMY)**.
#
# Voici les exigences auxquelles votre application doit répondre :
#
# Général
# - Une application de bureau qui fonctionne au minimum sur Windows. Si elle est compatible avec d'autres systèmes d'exploitation, c'est encore mieux ! Cette application doit respecter les fonctionnalités demandées ci-dessous. (55 pts)
# - Une couverture de tests de 100% (10 pts)
# - Respect du style de codage PEP8 (10 pts)
# - Une architecture maintenable conforme aux normes du marché (20 pts)
# - Respect des principes de codage propre (5 pts)
# - Votre application doit être adaptative (responsive) (5 pts)
# - Votre application doit respecter les normes de conception UX du marché et être facile à utiliser (5 pts)
# - Votre application doit être bien documentée et facile à utiliser dès la première utilisation (5 pts)
# - Votre application doit être suffisamment performante : nous ne devons pas observer de latence à l'écran lors de la manipulation du logiciel (20 pts)
#
# Fonctionnalités demandées (total 55 pts)
#
# 1. Permettre la visualisation du cours de l'action d'Olympus en dollars canadiens sur un graphique. (20 pts)
# 2. Permettre la visualisation du cours de l'action d'Olympus pour les périodes suivantes : (5 pts)
#     - Un jour
#     - Un mois
#     - Un an
# 3. Afficher la valeur maximale et minimale atteinte pendant la période sélectionnée à un endroit de l'écran. (5 pts)
# 4. Afficher en temps réel la valeur actuelle de l'action. (5 pts)
# 5. Permettre de dessiner des lignes : (20 pts)
#     - Permettre de dessiner des lignes horizontales de support ou de résistance qui représentent la valeur de l'action à la hauteur de la ligne sur le graphique. Voir les lignes mauves sur les images ci-dessous.
#     - Permettre de dessiner des lignes à un angle désiré pour suivre les tendances ascendantes ou descendantes du cours de l'action. Voir les lignes noires sur les images ci-dessous.
#     - Permettre de déplacer les deux types de lignes de haut en bas. Permettre également de déplacer les lignes en angles de gauche à droite.
#     - Assurer que les lignes dessinées restent visibles d'une vue à une autre, comme illustré sur les images ci-dessous. L'image d'une journée est en quelque sorte un zoom sur l'image d'une semaine.
#     - Permettre de supprimer les lignes individuellement, quelle que soit leur catégorie.
#
# Voici des images tirées d'un logiciel similaire. Nous avons étudié le cours de la cryptomonnaie Ethereum pour cet exemple. Votre produit devra nous fournir le cours de l'action d'Olympus.
#
# ![Alt text](One_week.jpg)
# <center>Figure 1 : Cours de l'Ethereum sur une période d'une semaine.</center>
#
# ![Alt text](One_day.jpg)
# <center>Figure 2 : Cours de l'Ethereum sur une période d'une journée.</center>
#
# Pour compléter cette question, nous vous invitons à créer autant de classes et de modules que vous le souhaitez dans le dossier de la Question 10.
#
# Afin de compléter cette question, nous vous invitons à créer le nombre de classes et de modules que vous voulez sous le dossier de la question 10.
#
# **Nous vous demandons de compléter la section ci-dessous en nous indiquant comment démarrer votre programme.**
#
# Les tests écris doivent respecter le fichier pytest.ini fournit dans le dossier "ignoredbypytest" de la question 10. Le linter doit également respecté le fichier de configuration de pycodestyle fournit dans le même dossier.
#
# **Si vous utilisez de nouvelles dépendances, veuillez les ajouter au fichier requirement.txt afin qu'elles soient automatiquement installées sur la machine du correcteur.**

# %% [markdown]
# ## Question 10: Creation of a small software for analyzing the stock price of Olympus.
#
# For those who may not know, before becoming Evident Scientific, this company was actually the industrial division of Olympus. In the past year, the company separated from the giant Olympus to become autonomous.
#
# In order to visualize the impact of selling a portion of the company on the stock price of Olympus, we request that you create a Python visualization tool for the stock price of Olympus.
#
# We ask that the data displayed in your application come from this [Yahoo Finance](https://docs.marketdata.app/api): Yahoo Finance. You can find the documentation for this API here: [Swagger](https://api.marketdata.app/#/v1/v1_indices_candles_retrieve). The specific stock we request you to track is: **Olympus Corporation (OLYMY)**.
#
# Here are the requirements your application must meet:
#
# General
# - A desktop application that runs on at least Windows. If it supports other operating systems, even better! This application must meet the requested functionalities below. (55 pts)
# - Have a test coverage of 100% (10 pts)
# - Adhere to PEP8 guidelines (10 pts)
# - Have a maintainable architecture that follows industry standards (20 pts)
# - Adhere to clean code principles (5 pts)
# - Your application is responsive (5 pts)
# - Your application follows industry UX design standards, is user-friendly (5 pts)
# - Your application is well-documented and easy to use for first-time users (5 pts)
# - Your application is performant: there should be no noticeable lag when using the software (20 pts)
#
# Requested functionalities (total 55 pts):
# 1. Allow visualizing the stock price of Olympus in Canadian dollars on a graph. (20 pts)
# 2. Enable viewing the stock price of Olympus over the following periods: (5 pts)
#     - One day
#     - One month
#     - One year
# 3. Display the maximum and minimum values reached within the selected period somewhere on the screen. (5 pts)
# 4. Display the current value of the stock at all times. (5 pts)
# 5. Enable drawing lines: (20 pts)
#     - Allow drawing a horizontal support or resistance line that represents the value of the stock at the height of that line on the graph. Refer to the purple lines in the images below.
#     - Allow drawing lines at a desired angle to track upward or downward trends in the stock price. Refer to the black lines in the images below.
#     - Allow moving both types of lines up and down. Also, allow moving the lines at angles from left to right.
#     - Ensure that the drawn lines persist from one view to another, as observed in the images below. The 1-day image is essentially a zoomed-in view of the 1-week image.
#     - Allow deleting all types of lines one by one.
#
#
#
# Here are some images taken from a similar software. We studied the price of the cryptocurrency Ethereum for this example. Your product should provide us with the stock price of Olympus.
#
# ![Alt text](One_week.jpg)
# <center>Figure 1 : Ethereum price over a one-week period.</center>
#
# ![Alt text](One_day.jpg)
# <center>Figure 2 : Ethereum price over a one-day period.</center>
#
# To complete this question, we invite you to create as many classes and modules as you need under the folder for Question 10.
#
# In order to complete this question, we invite you to create as many classes and modules as you want under the folder for Question 10.
#
# **Please complete the section below by indicating how to start your program.**
#
# The written tests should adhere to the pytest.ini file provided in the "ignoredbypytest" folder for Question 10. The linter should also adhere to the pycodestyle configuration file provided in the same folder.
#
# **If you are using new dependencies, please add them to the requirement.txt file so that they are automatically installed on the grader's machine.**

# %% [markdown]
# # Comment démarrer le logiciel | How to start the program
#
# //TODO by the competitor
