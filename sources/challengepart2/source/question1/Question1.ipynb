# %% [markdown]
# ## Question fichier HDF5
#
# Cette question comprend différents problèmes.
# Vous devrez implémenter les différentes questions dans le fichier suivant : **questions/question1/FileCreation.py**
#
# ---
# This question has many problems.
# You will need to implement the different questions in the following file: **questions/question1/FileCreation.py**
#
#
#
# ## Introduction
# L'utilisation de la suite technologique HDF5 est grandement répandu dans les différentes industries dans le but d'analyser, de gérer et de stocker des données. Il prend en charge une variété illimitée de types de données, conçu pour des E/S flexibles et efficaces et pour des données volumineuses et complexes. Pour en apprendre davantage sur la suite HDF5, vous pouvez consulter ce lien : https://www.hdfgroup.org/solutions/hdf5/.
# La première question a pour but de vous apprendre à lire et écrire des fichiers hdf5 qui est l'une des méthodes les plus répandues pour stocker les données chez Evident.
#
# Pour vous aider à lire les fichiers, je vous recommande deux outils soit myHdf5 en ligne : https://myhdf5.hdfgroup.org/ ou HdfView que vous pouvez télécharger ici : https://www.hdfgroup.org/downloads/hdfview/. Pour utiliser hdfView, vous pouvez regarder ce tutoriel : https://www.youtube.com/watch?v=q14F3WRwSck
#
# ---
#
# The HDF5 technology suite is widely used in different industries to analyze, manage and store data. It supports an unlimited variety of data types designed for flexible and efficient I/O and for large and complex data. To learn more about HDF5: you can consult this link: https://www.hdfgroup.org/solutions/hdf5/. The first question aims to teach you how to read and write files which is one of the most used methods for storing data at Evident.
#
# To Read HDF5 files, I recommend 2 tools either myHDF5 online: https://myhdf5.hdfgroup.org/ or HdfView which you can download here: https://www.hdfgroup.org/downloads/hdfview/. Tu use hdfView you can watch this tutorial: https://www.youtube.com/watch?v=q14F3WRwSck.
#
# ### Problem A (1.1)
# Dans le dossier Data, il y a 3 fichiers de données Amplitude.tiff, Status.bin et FiringSource.txt. Pour cette première question, je vous demande de créer un fichier hdf5 qui contient les 3 fichiers dans 3 datasets différents. Les datasets doivent respectivement avoir une dimensions de 22 x 49 x 620 pour l'Amplitude, 22 x 49 pour le Status et 22 x 49 pour le FiringSource.
# Le nom du fichier doit s'appeler ***EvidentChallenge.hdf5*** qui doit être créé dans le même répertoire que ce fichier soit **'source\questions\Question1'**. Les datasets doivent s'appeler ***Amplitude*** et ***Status*** et ***FiringSource***. Les DataType doivent être respectivement 16-bit integer pour l'amplitude, 8-bit unsigned integer pour le status et 16-bit integer pour le FiringSource.
#
# Cette question doit être répondu directement dans la méthode **CreateHdf5_Question1** de la classe FileCreation. Vous pouvez ajouter des 'helper functions' pour écrire le code (certains points seront attribués à l'architecture du code).
#
# Vous devez utiliser des paths relatifs pour cette question.
#
# ---
# In the Data folder there are 3 data files Amplitude.tiff, Status.bin and FiringSource.txt. For this first question, I'm asking you to create an hdf5 file that contains the 3 files in 3 different datasets. The datasets must respectively have dimensions of 22 x 49 x 620 for the Amplitude, 22 x 49 for the Status and 22 x 49 for the FiringSource.
# The name of the file must be called ***EvidentChallenge.hdf5*** which must be created in the same directory as this file is **'source\questions\Question1'**. The datasets must be called ***Amplitude*** and ***Status*** and ***FiringSource***. The DataTypes must be respectively 16-bit integer for the amplitude, 8-bit unsigned integer for the status and 16-bit integer for the FiringSource.
#
# This question must be answered directly in the **CreateHdf5_Question1** method of the FileCreation class. You can add 'helper functions' to write the code (some points will be given to the architecture of the code).
#
# You must use relative paths for this question.

# %% [markdown]
# ### Problem B (1.2)
#
# Maintenant que vous avez créé le fichier hdf5, nous allons analyser les données enregistrés. Veuillez vous référer à ce lien pour en apprendre davantage sur la théorie des Scans en PA: https://industrial.evidentscientific.com.cn/en/ndt-tutorials/instrumententation/phased-array-scans/.
# Pour lire sur la théorie PA en NDT veuillez vous référer à ce lien : https://www.nde-ed.org/NDETechniques/Ultrasonics/Introduction/description.xhtml
#
# ---
#
# Now that you have created the hdf5 file, let's analyze the recorded data. Please refer to this link to learn more about Theory of PA Scans: https://industrial.evidentscientific.com.cn/en/ndt-tutorials/instrumententation/phased-array-scans/. To read about PA theory in NDT please refer to this link: https://www.nde-ed.org/NDETechniques/Ultrasonics/Introduction/description.xhtml
#
# ***
#
#
# Question : Avec le/les fichiers que vous avez créés plus haut. Retournez les données d'amplitudes démontrée dans l'image ci-dessous.
#
# La question doit être répondue dans la fonction **get_answer_for_problem_B** de la classe FileCreation. La valeur retournée devrait être un array avec le même datatype enregistré dans la partie 1 pour le dataset d'amplitude.
#
# ---
#
# Question: With the file(s) you created above. Return the amplitude data demonstrated in the image below.
#
# The question should be answered in the **get_answer_for_problem_B** function of the FileCreation class. The returned value should be an array with the same datatype saved in part 1 for the amplitude dataset.

# %% [markdown]
# ![linearscan.PNG](attachment:linearscan.PNG)
#
# L'image ci-dessus correspond à une image de MXU avec les layouts de scans CScan, SScam, BScan et AScan. Vous pouvez consulter ce lien pour en apprendre davantage sur l'omniscan X3 : https://www.olympus-ims.com/en/phasedarray/omniscan-x3/
#
# ---
#
# The image above corresponds to an image of the omniPC with the active scans layout Cscan, Sscan, Bscan and Ascan. You can consult this link to learn more about omniPC and omniscan X3: https://www.olympus-ims.com/en/phasedarray/omniscan-x3/

# %% [markdown]
# ### Problem C (1.3)
#
# Pour la question 3, je vous demande d'offsetter (décaller) toutes les données d'amplitude par 50. Vous devez, enregistrer ces nouvelles données dans un fichier tiff que vous devez nommer AScanOffsetted.tiff. Le fichier doit se retrouver dans le même répertoire que le fichier EvidentChallenge.hdf5 créé soit **'source\questions\Question1'**.
#
# ---
#
# For question 3, I'm asking you to offset (shift) all the amplitude data by 50. You must save this new data in a tiff file which you must name AScanOffsetted.tiff. The file must be in the same directory as the EvidentChallenge.hdf5 file created, ie **'source\questions\Question1'**.
