# %% [markdown]
# ## Question 2 : SOLID priciples
#
# Cette question propose différents problèmes à choix de réponses.
# Vous devrez implémenter le choix de réponse de chaque problème dans le fichier suivant : **sources/challengepart2/source/question2/Solid_principles.py**
# ***
# This question includes multiple-choice issues.
# You will need to implement the answer for each issue in the following file: **sources/challengepart2/source/question2/Solid_principles.py**
#
# ### Problem A (2.1)
#
#
# Dans le code suivant, déterminer quel principe SOLID n'est pas respecté.
#
# ***
# Into the following code, determine which SOLID principle is not respected.
#
# Possible answer =>
#
# A : LSP
#
# B : ISP
#
# C : DIP
#
# D : OCP
#
# E : SRP
#
# <img src="../question2/assets/ICalibration.jpg" width="225" height="110">
#  <br />
# <img src="../question2/assets/CalibrationsBase.jpg" width="400" height="325">
#  <br />
# <img src="../question2/assets/DAC.jpg" width="400" height="300">
#  <br />
# <img src="../question2/assets/DistanceGainSizing.jpg" width="800" height="450">

# %% [markdown]
# ### Problem B (2.2)
#
# Dans le code suivant, déterminer quel principe SOLID n'est pas respecté.
#
# ***
# Into the following code, determine which SOLID principle is not respected.
#
# Possible answer =>
#
# A : LSP
#
# B : ISP
#
# C : DIP
#
# D : OCP
#
# E : SRP
#
# <img src="../question2/assets/Specimen.jpg" width="900" height="550">

# %% [markdown]
# ### Problem C (2.3)
#
# Dans le code suivant, déterminer quel principe SOLID n'est pas respecté.
#
# ***
# Into the following code, determine which SOLID principle is not respected.
#
# Possible answer =>
#
# A : LSP
#
# B : ISP
#
# C : DIP
#
# D : OCP
#
# E : SRP
#
# <img src="../question2/assets/ReadingInterface.jpg" width="300" height="250">
#  <br />
# <img src="../question2/assets/AmplitudeReading.jpg" width="750" height="400">
#
# <img src="../question2/assets/ThicknesssReading.jpg" width="750" height="400">

# %% [markdown]
# ### Problem D (2.4)
#
# Dans le code suivant, déterminer quel principe SOLID n'est pas respecté.
#
# ***
# Into the following code, determine which SOLID principle is not respected.
#
# Possible answer =>
#
# A : LSP
#
# B : ISP
#
# C : DIP
#
# D : OCP
#
# E : SRP
#
# <img src="../question2/assets/EvidentCloudConnection.jpg" width="700" height="700">

# %% [markdown]
# ### Problem E (2.5)
#
# Dans le code suivant, déterminer quel principe SOLID n'est pas respecté.
#
# ***
# Into the following code, determine which SOLID principle is not respected.
#
# Possible answer =>
#
# A : LSP
#
# B : ISP
#
# C : DIP
#
# D : OCP
#
# E : SRP
#
# <img src="../question2/assets/Omniscan.jpg" width="700" height="300">
